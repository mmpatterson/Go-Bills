# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

# %%
csv_2015 = pd.read_csv('~/Desktop/nflscrapR-data/play_by_play_data/regular_season/reg_pbp_2015 2.csv')
csv_2016 = pd.read_csv('~/Desktop/nflscrapR-data/play_by_play_data/regular_season/reg_pbp_2016 2.csv')
csv_2017 = pd.read_csv('~/Desktop/nflscrapR-data/play_by_play_data/regular_season/reg_pbp_2017 2.csv')
csv_2018 = pd.read_csv('~/Desktop/nflscrapR-data/play_by_play_data/regular_season/reg_pbp_2018 2.csv')
csv_2019 = pd.read_csv('~/Desktop/nflscrapR-data/play_by_play_data/regular_season/reg_pbp_2019 3.csv')
# Out:
# /Users/maxwellpatterson/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (42,167,168,175,176,179,180,183,184,189,190,191,192,204,205,206,227,228,232,233,234,239,241,242) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2016 = pd.DataFrame(csv_2016)
df_2016 = df_2016.loc[df_2016['passer_player_name'] == 'T.Taylor']

# %%
df_2016.head()
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 1265      216  2016091101       BAL       BUF     BUF         away     BAL
# 1267      261  2016091101       BAL       BUF     BUF         away     BAL
# 1276      476  2016091101       BAL       BUF     BUF         away     BAL
# 1278      521  2016091101       BAL       BUF     BUF         away     BAL
# 1292      836  2016091101       BAL       BUF     BUF         away     BAL
#
#      side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 1265           BUF          68.0  2016-09-11  ...                NaN
# 1267           BUF          72.0  2016-09-11  ...                NaN
# 1276           BAL          47.0  2016-09-11  ...                NaN
# 1278           BAL          43.0  2016-09-11  ...                NaN
# 1292           BUF          75.0  2016-09-11  ...                NaN
#
#       penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_2017 = pd.DataFrame(csv_2017)
df_2017 = df_2017.loc[(df_2017['passer_player_name'] == 'T.Taylor') | (df_2017['rusher_player_name'] == 'T.Taylor')]

# %%
df_2017.head()
# Out:
#      play_id     game_id home_team away_team posteam posteam_type defteam  \
# 204       55  2017091000       BUF       NYJ     BUF         home     NYJ
# 206      102  2017091000       BUF       NYJ     BUF         home     NYJ
# 208      162  2017091000       BUF       NYJ     BUF         home     NYJ
# 209      188  2017091000       BUF       NYJ     BUF         home     NYJ
# 213      284  2017091000       BUF       NYJ     BUF         home     NYJ
#
#     side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 204           BUF          75.0  2017-09-10  ...                NaN
# 206           BUF          72.0  2017-09-10  ...                NaN
# 208           BUF          69.0  2017-09-10  ...                NaN
# 209           BUF          69.0  2017-09-10  ...                NaN
# 213           NYJ          25.0  2017-09-10  ...                NaN
#
#      penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
pens_df2017 = df_2017.loc[df_2017['penalty'] == 1]
pens2017 = list(pens_df2017.index)

# %%
df_2017 = df_2017.drop(index = pens2017)

# %%
epa_2017 = df_2017['epa']

# %% [markdown]
# ## 2018 Season With Josh Allen

# %%
df_2018 = pd.DataFrame(csv_2018)
df_2018 = df_2018.loc[(df_2018['passer_player_name'] == 'J.Allen') | (df_2018['rusher_player_name'] == 'J.Allen')]

# %%
df_2018 = df_2018.set_index(list(df_2018)[0])
df_2018.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 1928     2018090900       BAL       BUF     BAL         home     BUF
# 2871     2018090900       BAL       BUF     BAL         home     BUF
# 2955     2018090900       BAL       BUF     BUF         away     BAL
# 2977     2018090900       BAL       BUF     BUF         away     BAL
# 3104     2018090900       BAL       BUF     BUF         away     BAL
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 1928              BUF          29.0  2018-09-09                      330.0
# 2871              BUF           1.0  2018-09-09                      686.0
# 2955              BUF          72.0  2018-09-09                      654.0
# 2977              BUF          72.0  2018-09-09                      649.0
# 3104              BUF          63.0  2018-09-09                      489.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
pens_df2018 = df_2018.loc[df_2018['penalty'] == 1]
pens2018 = list(pens_df2018.index)

# %%
df_2018 = df_2018.drop(index = pens2018)

# %%
epa_2018 = df_2018['epa']

# %%
hist2018 = df_2018.hist(column = 'epa', bins = 20)

# %% [markdown]
# ## 2018 Season with Darnold

# %%
df_sam2018 = pd.DataFrame(csv_2018)
df_sam2018 = df_sam2018.loc[(df_sam2018['passer_player_name'] == 'S.Darnold') | (df_sam2018['rusher_player_name'] == 'S.Darnold')]
df_sam2018.head()
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 2601       60  2018091000       DET       NYJ     NYJ         away     DET
# 2605      175  2018091000       DET       NYJ     NYJ         away     DET
# 2606      197  2018091000       DET       NYJ     NYJ         away     DET
# 2608      242  2018091000       DET       NYJ     NYJ         away     DET
# 2610      287  2018091000       DET       NYJ     NYJ         away     DET
#
#      side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 2601           NYJ          75.0  2018-09-10  ...                NaN
# 2605           NYJ          70.0  2018-09-10  ...                NaN
# 2606           NYJ          70.0  2018-09-10  ...                NaN
# 2608           NYJ          57.0  2018-09-10  ...                NaN
# 2610           DET          47.0  2018-09-10  ...                NaN
#
#       penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_sam2018 = df_sam2018.set_index(list(df_sam2018)[0])
df_sam2018.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 60       2018091000       DET       NYJ     NYJ         away     DET
# 175      2018091000       DET       NYJ     NYJ         away     DET
# 197      2018091000       DET       NYJ     NYJ         away     DET
# 242      2018091000       DET       NYJ     NYJ         away     DET
# 287      2018091000       DET       NYJ     NYJ         away     DET
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 60                NYJ          75.0  2018-09-10                      893.0
# 175               NYJ          70.0  2018-09-10                      803.0
# 197               NYJ          70.0  2018-09-10                      798.0
# 242               NYJ          57.0  2018-09-10                      712.0
# 287               DET          47.0  2018-09-10                      623.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
sampens_df2018 = df_sam2018.loc[df_sam2018['penalty'] == 1]
sampens2018 = list(sampens_df2018.index)

# %%
df_sam2018 = df_sam2018.drop(index = sampens2018)

# %%
epa_sam2018 = df_sam2018['epa']
epa_sam2018
# Out:
# play_id
# 60     -7.817075
# 175    -0.961229
# 197     2.498880
# 242     0.517210
# 287    -0.576128
# 330    -2.553070
# 494     0.518509
# 539    -0.550033
# 566     2.017322
# 785     0.136650
# 809     0.859065
# 872    -1.451991
# 1254   -0.115231
# 1278   -0.766445
# 1300    1.717912
# 1362    0.199280
# 1610    0.515142
# 1672    4.931169
# 2047   -0.814998
# 2258    1.111432
# 2357    1.452694
# 2402    2.845071
# 2782   -0.741452
# 3765    2.240145
# 3879    3.984216
# 3942   -0.583506
# 3980   -1.214041
# 4001   -0.689594
# 4022   -2.514126
# 177     1.672167
#           ...
# 667    -0.475715
# 713     1.642027
# 766    -0.741793
# 788    -1.004175
# 1370    0.437634
# 1395    0.555708
# 1422    0.535524
# 1494    2.463201
# 1525    0.556508
# 1595   -0.114387
# 1644   -2.255225
# 1888   -0.294108
# 1974    0.168522
# 2005   -3.190657
# 2215   -0.593678
# 2265   -8.529489
# 2398   -0.011897
# 2423    2.816871
# 2494    0.535014
# 2558   -0.695830
# 2582   -0.883147
# ...

# %% [markdown]
# ## 2019 Season with Darnold

# %%
df_sam2019 = pd.DataFrame(csv_2019)
df_sam2019 = df_sam2019.loc[(df_sam2019['passer_player_name'] == 'S.Darnold') | (df_sam2019['rusher_player_name'] == 'S.Darnold')]
df_sam2019.head()
# Out:
#      play_id     game_id home_team away_team posteam posteam_type defteam  \
# 561      280  2019090805       NYJ       BUF     NYJ         home     BUF
# 562      302  2019090805       NYJ       BUF     NYJ         home     BUF
# 581      864  2019090805       NYJ       BUF     NYJ         home     BUF
# 582      888  2019090805       NYJ       BUF     NYJ         home     BUF
# 585      965  2019090805       NYJ       BUF     NYJ         home     BUF
#
#     side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 561           NYJ          57.0  2019-09-08  ...                NaN
# 562           NYJ          57.0  2019-09-08  ...                NaN
# 581           NYJ          87.0  2019-09-08  ...                NaN
# 582           NYJ          83.0  2019-09-08  ...                NaN
# 585           NYJ          70.0  2019-09-08  ...                NaN
#
#      penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_sam2019 = df_sam2019.set_index(list(df_sam2019)[0])
df_sam2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 280      2019090805       NYJ       BUF     NYJ         home     BUF
# 302      2019090805       NYJ       BUF     NYJ         home     BUF
# 864      2019090805       NYJ       BUF     NYJ         home     BUF
# 888      2019090805       NYJ       BUF     NYJ         home     BUF
# 965      2019090805       NYJ       BUF     NYJ         home     BUF
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 280               NYJ          57.0  2019-09-08                      693.0
# 302               NYJ          57.0  2019-09-08                      689.0
# 864               NYJ          87.0  2019-09-08                      277.0
# 888               NYJ          83.0  2019-09-08                      248.0
# 965               NYJ          70.0  2019-09-08                      142.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
sampens_df2019 = df_sam2019.loc[df_sam2019['penalty'] == 1]
sampens2019 = list(sampens_df2019.index)

# %%
df_sam2019 = df_sam2019.drop(index = sampens2019)

# %%
epa_sam2019 = df_sam2019['epa']

# %% [markdown]
# ## 2019 Season Daniel Jones

# %%
df_jones2019 = pd.DataFrame(csv_2019)
df_jones2019 = df_jones2019.loc[(df_jones2019['passer_player_name'] == 'D.Jones') | (df_jones2019['rusher_player_name'] == 'D.Jones')]
df_jones2019.head()
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 2102     4049  2019090810       DAL       NYG     NYG         away     DAL
# 2103     4078  2019090810       DAL       NYG     NYG         away     DAL
# 2104     4107  2019090810       DAL       NYG     NYG         away     DAL
# 2105     4136  2019090810       DAL       NYG     NYG         away     DAL
# 2106     4162  2019090810       DAL       NYG     NYG         away     DAL
#
#      side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 2102           NYG          61.0  2019-09-08  ...                NaN
# 2103           NYG          56.0  2019-09-08  ...                NaN
# 2104           MID          50.0  2019-09-08  ...                NaN
# 2105           DAL          44.0  2019-09-08  ...                NaN
# 2106           DAL          44.0  2019-09-08  ...                NaN
#
#       penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_jones2019 = df_jones2019.set_index(list(df_jones2019)[0])
df_jones2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 4049     2019090810       DAL       NYG     NYG         away     DAL
# 4078     2019090810       DAL       NYG     NYG         away     DAL
# 4107     2019090810       DAL       NYG     NYG         away     DAL
# 4136     2019090810       DAL       NYG     NYG         away     DAL
# 4162     2019090810       DAL       NYG     NYG         away     DAL
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 4049              NYG          61.0  2019-09-08                      106.0
# 4078              NYG          56.0  2019-09-08                      102.0
# 4107              MID          50.0  2019-09-08                       96.0
# 4136              DAL          44.0  2019-09-08                       91.0
# 4162              DAL          44.0  2019-09-08                       85.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
jonespens_df2019 = df_jones2019.loc[df_jones2019['penalty'] == 1]
jonespens2019 = list(jonespens_df2019.index)

# %%
df_jones2019 = df_jones2019.drop(index = jonespens2019)

# %%
epa_jones2019 = df_jones2019['epa']

# %% [markdown]
# ## Baker 2019

# %%
df_baker2019 = pd.DataFrame(csv_2019)
df_baker2019 = df_baker2019.loc[(df_baker2019['passer_player_name'] == 'B.Mayfield') | (df_baker2019['rusher_player_name'] == 'B.Mayfield')]
df_baker2019.head()
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 1242       58  2019090801       CLE       TEN     CLE         home     TEN
# 1243       80  2019090801       CLE       TEN     CLE         home     TEN
# 1246      150  2019090801       CLE       TEN     CLE         home     TEN
# 1248      215  2019090801       CLE       TEN     CLE         home     TEN
# 1249      239  2019090801       CLE       TEN     CLE         home     TEN
#
#      side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 1242           CLE          73.0  2019-09-08  ...                NaN
# 1243           CLE          73.0  2019-09-08  ...                NaN
# 1246           TEN          42.0  2019-09-08  ...                NaN
# 1248           TEN          41.0  2019-09-08  ...                NaN
# 1249           TEN          39.0  2019-09-08  ...                NaN
#
#       penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_baker2019 = df_baker2019.set_index(list(df_baker2019)[0])
df_jones2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 4049     2019090810       DAL       NYG     NYG         away     DAL
# 4078     2019090810       DAL       NYG     NYG         away     DAL
# 4107     2019090810       DAL       NYG     NYG         away     DAL
# 4136     2019090810       DAL       NYG     NYG         away     DAL
# 4162     2019090810       DAL       NYG     NYG         away     DAL
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 4049              NYG          61.0  2019-09-08                      106.0
# 4078              NYG          56.0  2019-09-08                      102.0
# 4107              MID          50.0  2019-09-08                       96.0
# 4136              DAL          44.0  2019-09-08                       91.0
# 4162              DAL          44.0  2019-09-08                       85.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
bakerpens_df2019 = df_baker2019.loc[df_baker2019['penalty'] == 1]
bakerpens2019 = list(bakerpens_df2019.index)

# %%
df_baker2019 = df_baker2019.drop(index = bakerpens2019)

# %%
epa_baker2019 = df_baker2019['epa']

# %% [markdown]
# ## Lamar 2019

# %%
df_lamar2019 = pd.DataFrame(csv_2019)
df_lamar2019 = df_lamar2019.loc[(df_lamar2019['passer_player_name'] == 'L.Jackson') | (df_lamar2019['rusher_player_name'] == 'L.Jackson')]
df_lamar2019.head()
# Out:
#      play_id     game_id home_team away_team posteam posteam_type defteam  \
# 904       90  2019090803       MIA       BAL     BAL         away     MIA
# 906      135  2019090803       MIA       BAL     BAL         away     MIA
# 918      408  2019090803       MIA       BAL     BAL         away     MIA
# 928      661  2019090803       MIA       BAL     BAL         away     MIA
# 929      683  2019090803       MIA       BAL     BAL         away     MIA
#
#     side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 904           MIA          40.0  2019-09-08  ...                NaN
# 906           MIA          22.0  2019-09-08  ...                NaN
# 918           MIA          47.0  2019-09-08  ...                NaN
# 928           BAL          86.0  2019-09-08  ...                NaN
# 929           BAL          83.0  2019-09-08  ...                NaN
#
#      penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_lamar2019 = df_lamar2019.set_index(list(df_lamar2019)[0])
df_lamar2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 90       2019090803       MIA       BAL     BAL         away     MIA
# 135      2019090803       MIA       BAL     BAL         away     MIA
# 408      2019090803       MIA       BAL     BAL         away     MIA
# 661      2019090803       MIA       BAL     BAL         away     MIA
# 683      2019090803       MIA       BAL     BAL         away     MIA
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 90                MIA          40.0  2019-09-08                      849.0
# 135               MIA          22.0  2019-09-08                      770.0
# 408               MIA          47.0  2019-09-08                      526.0
# 661               BAL          86.0  2019-09-08                      311.0
# 683               BAL          83.0  2019-09-08                      268.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
lamarpens_df2019 = df_lamar2019.loc[df_lamar2019['penalty'] == 1]
lamarpens2019 = list(lamarpens_df2019.index)

# %%
df_lamar2019 = df_lamar2019.drop(index = lamarpens2019)

# %%
epa_lamar2019 = df_lamar2019['epa']

# %% [markdown]
# ## Mahomes

# %%
df_mahomes2019 = pd.DataFrame(csv_2019)
df_mahomes2019 = df_mahomes2019.loc[(df_mahomes2019['passer_player_name'] == 'P.Mahomes') | (df_mahomes2019['rusher_player_name'] == 'P.Mahomes')]
df_mahomes2019.head()

df_mahomes2019 = df_mahomes2019.set_index(list(df_mahomes2019)[0])
df_mahomes2019.head()

mahomespens_df2019 = df_mahomes2019.loc[df_mahomes2019['penalty'] == 1]
mahomespens2019 = list(mahomespens_df2019.index)

df_mahomes2019 = df_mahomes2019.drop(index = mahomespens2019)

epa_mahomes2019 = df_mahomes2019['epa']

# %% [markdown]
# ## Teddy

# %%
df_teddy2015 = pd.DataFrame(csv_2015)
df_teddy2015 = df_teddy2015.loc[(df_teddy2015['passer_player_name'] == 'T.Bridgewater') | (df_teddy2015['rusher_player_name'] == 'T. Bridgewater')]
df_teddy2015.head()

df_teddy2015 = df_teddy2015.set_index(list(df_teddy2015)[0])
df_teddy2015.head()

teddypens_df2015 = df_teddy2015.loc[df_teddy2015['penalty'] == 1]
teddypens2015 = list(teddypens_df2015.index)

df_teddy2015 = df_teddy2015.drop(index = teddypens2015)

epa_teddy2015 = df_teddy2015['epa']

# %%
df_teddy2019 = pd.DataFrame(csv_2019)
df_teddy2019 = df_teddy2019.loc[(df_teddy2019['passer_player_name'] == 'T.Bridgewater') | (df_teddy2019['rusher_player_name'] == 'T. Bridgewater')]
df_teddy2019.head()

df_teddy2019 = df_teddy2019.set_index(list(df_teddy2019)[0])
df_teddy2019.head()

teddypens_df2019 = df_teddy2019.loc[df_teddy2019['penalty'] == 1]
teddypens2019 = list(teddypens_df2019.index)

df_teddy2019 = df_teddy2019.drop(index = teddypens2019)

epa_teddy2019 = df_teddy2019['epa']

# %% [markdown]
# ## Russell Wilson

# %%
df_russell2019 = pd.DataFrame(csv_2019)
df_russell2019 = df_russell2019.loc[(df_russell2019['passer_player_name'] == 'R.Wilson') | (df_russell2019['rusher_player_name'] == 'R.Wilson')]
df_russell2019.head()
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 1594      311  2019090808       SEA       CIN     SEA         home     CIN
# 1595      336  2019090808       SEA       CIN     SEA         home     CIN
# 1615      793  2019090808       SEA       CIN     SEA         home     CIN
# 1618      887  2019090808       SEA       CIN     SEA         home     CIN
# 1621      949  2019090808       SEA       CIN     SEA         home     CIN
#
#      side_of_field  yardline_100   game_date  ...  penalty_player_id  \
# 1594           SEA          79.0  2019-09-08  ...                NaN
# 1595           SEA          79.0  2019-09-08  ...                NaN
# 1615           SEA          72.0  2019-09-08  ...                NaN
# 1618           CIN          43.0  2019-09-08  ...                NaN
# 1621           CIN          32.0  2019-09-08  ...                NaN
#
#       penalty_player_name  penalty_yards replay_or_challenge  \
# ...

# %%
df_russell2019 = df_russell2019.set_index(list(df_russell2019)[0])
df_russell2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 311      2019090808       SEA       CIN     SEA         home     CIN
# 336      2019090808       SEA       CIN     SEA         home     CIN
# 793      2019090808       SEA       CIN     SEA         home     CIN
# 887      2019090808       SEA       CIN     SEA         home     CIN
# 949      2019090808       SEA       CIN     SEA         home     CIN
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 311               SEA          79.0  2019-09-08                      684.0
# 336               SEA          79.0  2019-09-08                      679.0
# 793               SEA          72.0  2019-09-08                      136.0
# 887               CIN          43.0  2019-09-08                       40.0
# 949               CIN          32.0  2019-09-08                      900.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
russellpens_df2019 = df_russell2019.loc[df_russell2019['penalty'] == 1]
russellpens2019 = list(russellpens_df2019.index)

# %%
df_russell2019 = df_russell2019.drop(index = russellpens2019)

# %%
epa_russell2019 = df_russell2019['epa']

# %% [markdown]
# ## 2019 Season With Josh Allen

# %%
df_2019 = pd.DataFrame(csv_2019)
df_2019 = df_2019.loc[(df_2019['passer_player_name'] == 'J.Allen') | (df_2019['rusher_player_name'] == 'J.Allen')]

# %%
df_2019 = df_2019.set_index(list(df_2019)[0])
df_2019.head()
# Out:
#             game_id home_team away_team posteam posteam_type defteam  \
# play_id
# 51       2019090805       NYJ       BUF     BUF         away     NYJ
# 75       2019090805       NYJ       BUF     BUF         away     NYJ
# 127      2019090805       NYJ       BUF     BUF         away     NYJ
# 151      2019090805       NYJ       BUF     BUF         away     NYJ
# 175      2019090805       NYJ       BUF     BUF         away     NYJ
#
#         side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# play_id
# 51                BUF          75.0  2019-09-08                      900.0
# 75                BUF          67.0  2019-09-08                      866.0
# 127               NYJ          49.0  2019-09-08                      827.0
# 151               NYJ          40.0  2019-09-08                      799.0
# 175               NYJ          36.0  2019-09-08                      769.0
#
#          ...  penalty_player_id  penalty_player_name penalty_yards  \
# ...

# %%
# df_2019.drop(df_2019.loc[df_2019['penalty'] == 1])
pens_df2019 = df_2019.loc[df_2019['penalty'] == 1]
pens2019 = list(pens_df2019.index)

# %%
df_2019 = df_2019.drop(index = pens2019)

# %%
epa_2019 = df_2019['epa']

# %%
# df_2019['epa']
# xticks2019 = [-7, -6.8, -6.6, -6.4, -6.2, -6, -5.8, -5.6, -5.4, -5.2, -5, -4.8, -4.6, -4.4, -4.2, -4, -3.8, -3.6, -3.4, -3.2, -3, -2.8, -2.6, -2.4, -2.2, -2, -1.8, -1.6, -1.4, -1.2, -1, -.8, -.6, -.4, -.2, 0, .2, .4, .6, .8, 1, 1.2, 1.4, 1.6, 1.8, 2, 2.2, 2.4, 2.6, 2.8, 3, 3.2, 3.4, 3.6, 3.8, 4, 4.2, 4.4, 4.6, 4.8, 5, 5.2, 5.4, 5.6, 5.8, 6, 6.2, 6.4, 6.6, 6.8, 7]
hist2019 = df_2019.hist(column = 'epa', bins = 20)

# %%
df_2019['epa']
# Out:
# play_id
# 51      0.861847
# 75      0.980175
# 127     0.180691
# 151    -0.105505
# 175     0.744784
# 199    -0.452979
# 356    -6.608273
# 532     0.096394
# 598    -0.023127
# 730     0.147791
# 754    -0.721413
# 776     1.074533
# 521    -0.462924
# 554    -0.475773
# 1106   -0.780327
# 1136   -1.644684
# 1497    0.628624
# 1521    0.490562
# 1579    2.078983
# 1620   -0.482303
# 1659    0.323557
# 1680   -1.375960
# 1701   -2.794870
# 1821   -0.059742
# 1867   -0.000637
# 1901    1.549507
# 1930   -0.274034
# 1952   -3.425130
# 2181   -0.814998
# 2956   -0.909398
#           ...
# 550     0.595016
# 583     0.682546
# 632    -0.098141
# 660    -0.786804
# 681    -1.243844
# 952     2.780713
# 1062    1.694953
# 1122   -0.048040
# 1143   -0.713900
# 1180   -1.020746
# 1441    0.172781
# 1767    0.500895
# 1855    0.092482
# 1879   -0.274166
# 2084   -1.009705
# 2106    3.321465
# 2189   -0.430309
# 2211   -0.752436
# 2237    3.726413
# 2800   -0.945656
# 2823   -1.346006
# ...

# %% [markdown]
# ## Allen, 2018 vs. 2019

# %%
legend = ['2018 EPA', '2019 EPA']
plt.hist([epa_2018, epa_2019], color=['red', 'blue'], bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Allen's Run/Pass EPA on play, 2018 vs. 2019")
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/allen_epa_2018_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/allen_epa_2018_2019.png')

# %% [markdown]
# ## The unthinkable

# %%
legend = ['Tyrod 2017', 'Allen 2019']
plt.hist([epa_2017, epa_2019], color=['red', 'blue'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Tyrod vs. Allen Run/Pass EPA on play, 2018 vs. 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/tyrod_v_allen_epa_2017_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/allen_epa_2018_2019.png')

# %%
legend = ['Darnold 2019', 'Allen 2019']
plt.hist([epa_sam2019, epa_2019], color=['forestgreen', 'blue'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Darnold vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/darnold_v_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/allen_epa_2018_2019.png')

# %% [markdown]
# ## Darnold 2018 vs 2019

# %%
legend = ['Darnold 2018', 'Darnold 2019']
plt.hist([epa_sam2018, epa_sam2019], color=['green', 'black'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Darnold Run/Pass EPA on play, 2018 vs. 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/darnold_epa_2018_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %% [markdown]
# ## Jones vs. Allen 2019

# %%
epa_jones2019

legend = ['Jones 2019', 'Allen 2019']
plt.hist([epa_jones2019, epa_2019], color=['blue', 'red'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Jones vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/jones_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %%
legend = ['Baker 2019', 'Allen 2019']
plt.hist([epa_baker2019, epa_2019], color=['darkorange', 'blue'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Baker vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/baker_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %%
legend = ['Lamar 2019', 'Allen 2019']
plt.hist([epa_lamar2019, epa_2019], color=['purple', 'red'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 7), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Lamar vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/lamar_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %%
legend = ['Russell 2019', 'Allen 2019']
plt.hist([epa_russell2019, epa_2019], color=['slategrey', 'blue'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-10, 6), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Russell vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/russell_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %%
legend = ['Mahomes 2019', 'Allen 2019']
plt.hist([epa_mahomes2019, epa_2019], color=['red', 'blue'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 8), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Mahomes vs. Allen Run/Pass EPA on play, 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/mahomes_allen_epa_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')

# %%
legend = ['Teddy 2015', 'Teddy 2019']
plt.hist([epa_teddy2015, epa_teddy2019], color=['purple', 'gold'], alpha = .78, bins = 24, density = True)
plt.xlabel("EPA on Play")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(range(-7, 8), fontsize=10)
# plt.yticks(range(1, 20))
plt.title("Teddy Run/Pass EPA on play, 2015 vs. 2019")
plt.annotate('Data courtesy of nflscrapR', (.25,0), (0, -40), xycoords='axes fraction', textcoords='offset points', va='top')
# plt.tight_layout()
# plt.show()

# fig = plt.gcf()
# fig.show()
plt.savefig('figures/teddy_epa_2015_vs_2019', dpi=300, bbox_inches='tight', style = 'fivethirtyeight')
# fig.savefig('figures/darnold_epa_2018_2019.png')
